# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

import pickle
from multiprocessing import Pool

import modeling
import helpers
import plotting
import scienceplots
plt.style.use(['science','no-latex'])
# plt.style.use(['science','ieee','no-latex'])

# %% [markdown]
# # Load data

# %%
with open('data.pkl', 'rb') as file:
    data_dict = pickle.load(file)
    all_data = data_dict['data']
    meta_data = data_dict['meta_data']

best_params_all_backward = np.load('fitting_results/backward_params.npy')
best_params_all_backward_no_meta = np.load('fitting_results/backward_no_meta_params.npy')

# %% [markdown]
# # Parameter recovery

# %% [markdown]
# ## V1-V1, Cluster 0, backward meta-learning model

# %%
this_model = 'option_model'
structure = 'backward'
meta_learning = True
cluster = 0
condition = 'All'
fitted_params = best_params_all_backward[(meta_data['Cluster']==cluster) & (meta_data['Condition']=='V1-V1')]
num_subject = fitted_params.shape[0]

alpha_bounds = [1e-6, 1]
beta_bounds = [1e-6, 10]
concentration_bounds = [-2, 1]
epsilon_bounds = [1e-6, 0.99]
bounds = [alpha_bounds, concentration_bounds, epsilon_bounds] 
param_names = ["alpha_2", 'concentration_2', 'epsilon']

best_llh_all = np.zeros(num_subject)
best_params_all = np.zeros((num_subject, len(param_names)))

all_sim_data = {}

if __name__ == "__main__":
    inputs = []
       
    for i in range(num_subject):
        alpha_2, concentration_2, epsilon, _ = fitted_params[i]
        inputs.append((this_model, i, 1, alpha_2, concentration_2, epsilon, condition, structure, meta_learning))
        
        
    with Pool() as p:
        results = p.map(modeling.parallel_simulator, inputs)
        
    inputs = []
        
    for i, this_data in results:
        all_sim_data = helpers.concatenate_data(this_data, all_sim_data)
        D = helpers.get_model_fit_data(this_data, num_block=6)  
        inputs.append((this_model, D, structure, i, bounds, meta_learning))

    with Pool() as p:
        results = p.map(modeling.parallel_worker, inputs)

    for i, best_params, best_llh in results:
        best_params_all[i, :], best_llh_all[i] = best_params, best_llh

np.save(f'fitting_results/paramrec_{structure}_{condition}_cluster{cluster}_params.npy', best_params_all)
np.save(f'fitting_results/paramrec_{structure}_{condition}_cluster{cluster}_llh.npy', best_llh_all)

# %%
plt.figure(figsize=(9,9))
for p in range(len(bounds)):
    for q in range(len(bounds)):
        ax = plt.subplot(len(bounds), len(bounds), p*len(bounds)+q+1)
        p_bounds = bounds[p].copy()
        q_bounds = bounds[q].copy()

        values_p = fitted_params[:,p]
        values_q = best_params_all[:,q]
        if 'concentration' in param_names[p]:
            p_bounds[0] = 10**p_bounds[0]
            p_bounds[1] = 10**p_bounds[1]
            values_p = 10**values_p
        if 'concentration' in param_names[q]:
            q_bounds[0] = 10**q_bounds[0]
            q_bounds[1] = 10**q_bounds[1]
            values_q = 10**values_q
        plt.plot(values_p, values_q, '.')
        plt.plot([p_bounds[0],p_bounds[1]], [q_bounds[0], q_bounds[1]])
        plt.xlim(p_bounds)
        plt.ylim(q_bounds)
        plt.xlabel(f'True {param_names[p]}')
        plt.ylabel(f'Recovered {param_names[q]}')
        ax.set_box_aspect(1)

plt.suptitle(f'Parameter recovery for {this_model}, Cluster {cluster}, {experiment}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Blocks 1-6, Cluster 0, backward no meta-learning model

# %%
this_model = 'option_model'
structure = 'backward'
meta_learning = False
cluster = 0
condition = 'All'
fitted_params = best_params_all_backward_no_meta[(meta_data['Cluster']==cluster)]
num_subject = fitted_params.shape[0]

alpha_bounds = [1e-6, 0.99]
beta_bounds = [1e-6, 10]
concentration_bounds = [-2, 1]
epsilon_bounds = [1e-6, 0.99]
bounds = [alpha_bounds] 
param_names = ["alpha_2"]

best_llh_all = np.zeros(num_subject)
best_params_all = np.zeros((num_subject, len(param_names)))

all_sim_data = {}

if __name__ == "__main__":
    inputs = []
       
    for i in range(num_subject):
        alpha_2, concentration_2 = fitted_params[i]
        params = [alpha_2]
        inputs.append((this_model, i, 1, params, condition, structure, meta_learning))
        
        
    with Pool() as p:
        results = p.map(modeling.parallel_simulator, inputs)
        
    inputs = []
        
    for i, this_data in results:
        all_sim_data = helpers.concatenate_data(this_data, all_sim_data)
        D = helpers.get_model_fit_data(this_data, num_block=1)  
        inputs.append((this_model, D, structure, i, bounds, meta_learning))

    with Pool() as p:
        results = p.map(modeling.parallel_worker, inputs)

    for i, best_params, best_llh in results:
        best_params_all[i, :], best_llh_all[i] = best_params, best_llh

np.save(f'fitting_results/paramrec_{structure}_no_meta_{condition}_cluster{cluster}_params.npy', best_params_all)
np.save(f'fitting_results/paramrec_{structure}_no_meta_{condition}_cluster{cluster}_llh.npy', best_llh_all)

# %%
plt.figure(figsize=(9,9))
for p in range(len(bounds)):
    for q in range(len(bounds)):
        ax = plt.subplot(len(bounds), len(bounds), p*len(bounds)+q+1)
        p_bounds = bounds[p].copy()
        q_bounds = bounds[q].copy()

        values_p = fitted_params[:,p]
        values_q = best_params_all[:,q]
        if 'concentration' in param_names[p]:
            p_bounds[0] = 10**p_bounds[0]
            p_bounds[1] = 10**p_bounds[1]
            values_p = 10**values_p
        if 'concentration' in param_names[q]:
            q_bounds[0] = 10**q_bounds[0]
            q_bounds[1] = 10**q_bounds[1]
            values_q = 10**values_q
        plt.plot(values_p, values_q, '.')
        plt.plot([p_bounds[0],p_bounds[1]], [q_bounds[0], q_bounds[1]])
        plt.xlim(p_bounds)
        plt.ylim(q_bounds)
        plt.xlabel(f'True {param_names[p]}')
        plt.ylabel(f'Recovered {param_names[q]}')
        ax.set_box_aspect(1)

plt.suptitle(f'Parameter recovery for {this_model}, Cluster {cluster}, {condition}')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Likelihood landscape

# %%
this_model = 'option_model'
structure = 'backward'
meta_learning = False
cluster = 0
condition = 'All'

llhs = []
true_alphas = np.arange(0.1,1,0.1)
alphas_eval = np.arange(0.01,1,0.01)
llhs = np.zeros_like(alphas_eval)
beta = 5
concentration_2 = -1
epsilon = 0.1
prior = 0

for alpha in true_alphas:
    this_data = modeling.option_model(1, [alpha], 'All', structure, meta_learning)
    D = helpers.get_model_fit_data(this_data, num_block=6)
    for i in range(len(alphas_eval)):
        alpha_2 = alphas_eval[i]
        params = alpha_2
        llhs[i] = modeling.option_model_nllh(params, D, structure, meta_learning)

    plt.plot(alphas_eval, llhs, label=f'True alpha = {alpha:.1f}')

plt.xlabel('Alpha')
plt.ylabel('NLLH')
plt.legend()
plt.show()
# Out:
# [0.25 0.25 0.25 0.25]
# [0.25756621 0.22730138 0.25756621 0.25756621]
# [0.25 0.25 0.25 0.25]
# [0.14202341 0.14202341 0.56659374 0.14935944]
# [0.63813244 0.20395127 0.06789666 0.09001963]
# [0.13325739 0.12276476 0.30191206 0.4420658 ]
# [0.12406654 0.12406654 0.3051135  0.44675342]
# [0.12517152 0.11626519 0.30783094 0.45073235]
# [0.13127709 0.12193633 0.27406855 0.47271802]
# [0.13231405 0.11500054 0.27623341 0.476452  ]
# [0.13752092 0.11952609 0.24775144 0.49520154]
# [0.12899815 0.12070722 0.25019965 0.50009498]
# [0.10991091 0.10284675 0.21317882 0.57406352]
# [0.11290142 0.10564505 0.19177062 0.5896829 ]
# [0.11539213 0.10797568 0.17394035 0.60269184]
# [0.12007387 0.12007387 0.63357614 0.12627612]
# [0.13620839 0.6972684  0.08633303 0.08019018]
# [0.11649383 0.74108524 0.07383734 0.06858359]
# [0.10164524 0.10164524 0.68981395 0.10689558]
# [0.68770318 0.17601283 0.05859577 0.07768822]
# [0.72895465 0.15276319 0.05085582 0.06742633]
# [0.10041951 0.77681139 0.06364895 0.05912014]
# [0.09734095 0.09108468 0.14673028 0.66484408]
# [0.08648101 0.08648101 0.73608991 0.09094807]
# [0.07414126 0.07414126 0.77374655 0.07797093]
# [0.07457663 0.0687045  0.7782901  0.07842878]
# [0.06447238 0.05939585 0.80832916 0.06780261]
# [0.08735969 0.80583766 0.05537124 0.05143141]
# [0.07674468 0.82943018 0.04864312 0.04518202]
# [0.76301038 0.13356913 0.044466   0.05895449]
# [0.08238388 0.07708892 0.12418421 0.71634299]
# [0.07018189 0.06567118 0.10579113 0.75835579]
# [0.05630197 0.05186878 0.83261908 0.05921017]
# [0.04967548 0.04576405 0.85231907 0.0522414 ]
# [0.06030398 0.05642814 0.09090131 0.79236656]
# [0.05232503 0.04896201 0.07887395 0.81983901]
# [0.04587021 0.04292205 0.06914406 0.84206368]
# [0.06809083 0.84866391 0.04315804 0.04008722]
# [0.04062803 0.0380168  0.06124208 0.86011309]
# [0.79103777 0.11777268 0.03920726 0.05198229]
# [0.81410925 0.10476942 0.0348784  0.04624293]
# [0.06100312 0.86441678 0.03866564 0.03591446]
# [0.0442754  0.04078918 0.86837303 0.04656239]
# [0.83314803 0.09403902 0.03130618 0.04150677]
# [0.03634794 0.03401179 0.05479033 0.87484994]
# [0.05516583 0.87739052 0.03496579 0.03247787]
# [0.03283194 0.03072178 0.04949038 0.8869559 ]
# [0.84892012 0.08514975 0.02834689 0.03758324]
# [0.86204777 0.07775091 0.02588377 0.03431755]
# [0.03984914 0.03671144 0.88153193 0.04190749]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[61], line 18
#      16 for alpha in true_alphas:
#      17     this_data = modeling.option_model(1, [alpha], 'All', structure, meta_learning)
# ---> 18     D = helpers.get_model_fit_data(this_data, num_block=6)
#      19     for i in range(len(alphas_eval)):
#      20         alpha_2 = alphas_eval[i]
#
# File ~/Desktop/jingjing/learning_hierarchy/helpers.py:988, in get_model_fit_data(data, num_block)
#     986 b_1 = 1
#     987 for trial in range(num_trial_else):
# --> 988   s_1 = s1[sub,b,trial] - 1
#     989   if np.isnan(counter1[sub,b,trial]):
#     990     continue
#
# IndexError: index 0 is out of bounds for axis 1 with size 0
